# %%
pip install spacy spacy tabulate
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/12.8 MB 1.5 MB/s eta 0:00:08
#      --- ------------------------------------ 1.0/12.8 MB 1.6 MB/s eta 0:00:08
#      ---- ----------------------------------- 1.3/12.8 MB 1.5 MB/s eta 0:00:08
#      ---- ----------------------------------- 1.6/12.8 MB 1.6 MB/s eta 0:00:08
#      ------ --------------------------------- 2.1/12.8 MB 1.6 MB/s eta 0:00:07
#      ------ --------------------------------- 2.1/12.8 MB 1.6 MB/s eta 0:00:07
#      -------- ------------------------------- 2.6/12.8 MB 1.5 MB/s eta 0:00:07
#      --------- ------------------------------ 2.9/12.8 MB 1.5 MB/s eta 0:00:07
#      --------- ------------------------------ 3.1/12.8 MB 1.5 MB/s eta 0:00:07
# ...

# %%
# Step-1

import spacy
from tabulate import tabulate

# Step-2
# Make sure model is installed using:
# python -m spacy download en_core_web_sm
nlp = spacy.load("en_core_web_sm")

# Step-3
interrogative_sentence = input("Enter an interrogative sentence: ")
declarative_sentence = input("Enter a declarative sentence: ")
complex_sentence = input("Enter a complex sentence: ")

# Step-4
interrogative_doc = nlp(interrogative_sentence)
declarative_doc = nlp(declarative_sentence)
complex_doc = nlp(complex_sentence)

# Step-5
interrogative_pos = [(token.text, token.pos_, token.morph) for token in interrogative_doc]
declarative_pos = [(token.text, token.pos_, token.morph) for token in declarative_doc]
complex_pos = [(token.text, token.pos_, token.morph) for token in complex_doc]

# Step-6
table_headers = ["Word", "POS Tag", "Morphological Features"]

# Step-7
interrogative_table = tabulate(interrogative_pos, headers=table_headers, tablefmt="pretty")
declarative_table = tabulate(declarative_pos, headers=table_headers, tablefmt="pretty")
complex_table = tabulate(complex_pos, headers=table_headers, tablefmt="pretty")

# Step-8
print("\nInterrogative Sentence Morphological Analysis:")
print(interrogative_table)

print("\nDeclarative Sentence Morphological Analysis:")
print(declarative_table)

print("\nComplex Sentence Morphological Analysis:")
print(complex_table)
# Out:
# Enter an interrogative sentence:  What are you doing today?
# Enter a declarative sentence:  She is reading a book in the library.
# Enter a complex sentence:  Although it was raining, we decided to go for a walk.
# Interrogative Sentence Morphological Analysis:
# +-------+---------+--------------------------------------+
# | Word  | POS Tag |        Morphological Features        |
# +-------+---------+--------------------------------------+
# | What  |  PRON   |                                      |
# |  are  |   AUX   |   Mood=Ind|Tense=Pres|VerbForm=Fin   |
# |  you  |  PRON   |    Case=Nom|Person=2|PronType=Prs    |
# | doing |  VERB   | Aspect=Prog|Tense=Pres|VerbForm=Part |
# | today |  NOUN   |             Number=Sing              |
# |   ?   |  PUNCT  |            PunctType=Peri            |
# +-------+---------+--------------------------------------+
#
# Declarative Sentence Morphological Analysis:
# ...
